# %%
from newsapi import NewsApiClient
from dotenv import load_dotenv
import os

load_dotenv(override=True)
# Out:
# True

# %%
news_api_key = os.getenv("NEWS_API_KEY")
if not news_api_key:
    print("NEWS_API_KEY environment variable not set.")

# %%
newsapi = NewsApiClient(api_key=news_api_key)

top_headlines = newsapi.get_top_headlines(country='us', language='en', page_size=100)

top_headlines["articles"]
# Out:
# [{'source': {'id': None, 'name': 'CBS Sports'},
#   'author': 'Tyler Sullivan',
#   'title': 'NFL preseason week 2 schedule, live updates, scores, highlights: Quinn Ewers tosses first TD - CBS Sports',
#   'description': 'Everything to know about the second week of the preseason right here',
#   'url': 'https://www.cbssports.com/nfl/news/nfl-preseason-week-2-schedule-live-updates-scores-highlights-dolphins-quinn-ewers-tosses-first-td/live/',
#   'urlToImage': 'https://sportshub.cbsistatic.com/i/r/2025/08/10/d2975724-9aa8-4945-8cb3-e6c6b7a0d1ed/thumbnail/1200x675/37f63e27aecb5e5843e3b19f11455558/ewers.jpg',
#   'publishedAt': '2025-08-16T19:59:38Z',
#   'content': 'Week 2 of the NFL preseason kicked off on Friday with two games as the Titans topped the Falcons and the Seahawks upended the Chiefs. A total of 11 games are on tap for Saturday, starting with 5 game… [+1169 chars]'},
#  {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#   'author': None,
#   'title': 'Israel prepares to move Palestinians to southern Gaza as Israelis urge mass protest over war - AP News',
#   'description': 'Israel says it is preparing to move Palestinians from combat zones to southern Gaza as plans move ahead for a military offensive in some of the territory’s most populated areas. Anxious families of hostages have called for a “nationwide day of stoppage” in Is…',
#   'url': 'https://apnews.com/article/gaza-israel-palestinians-hamas-war-878bdc43a5c5fdaecdb1cb4cff92d2fd',
#   'urlToImage': 'https://dims.apnews.com/dims4/default/e312b68/2147483647/strip/true/crop/5190x2919+0+270/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2Ff3%2Fb6%2Fc2b09e16404d37076846f9e416e0%2Fd687aeb3c82c4d45a4ab5f1c4b24170c',
#   'publishedAt': '2025-08-16T18:20:00Z',
#   'content': 'NAHARIYA, Israel (AP) Israel announced Saturday that it is preparing to move Palestinians from combat zones to southern Gaza as plans move ahead for a military offensive in some of the territorys mos… [+4677 chars]'},
#  {'source': {'id': None, 'name': 'Hollywood Reporter'},
#   'author': 'Pamela McClintock',
#   'title': 'Box Office: ‘Nobody 2’ Can’t Stop ‘Weapons’ as Sydney Sweeney’s ‘Americana’ All-Out Bombs - The Hollywood Reporter',
#   'description': "Spike Lee's Denzel Washington-starrer 'Highest 2 Lowest' also may be struggling in its limited theatrical debut before landing relatively quickly on Apple TV+.",
#   'url': 'http://www.hollywoodreporter.com/movies/movie-news/weapons-box-office-nobody-2-highest-to-lowest-1236346020/',
#   'urlToImage': 'https://www.hollywoodreporter.com/wp-content/uploads/2025/08/Nobody-2-Embed-3-2025.jpg?w=1047&h=748&crop=1',
#   'publishedAt': '2025-08-16T17:27:51Z',
#   'content': 'Bob Odenkirk’s modestly budgeted sequel Nobody 2 is having to settle for a third-place finish in its domestic box office debut as Zach Cregger’s horror pic, Weapons, continues to fire on all cylinder… [+2688 chars]'},
#  {'source': {'id': 'axios', 'name': 'Axios'},
#   'author': 'Lauren Floyd',
#   'title': 'Hurricane Erin strengthens to Category 5 - Axios',
#   'description': 'Erin is forecast to bring heavy rainfall through Sunday and "life-threatening surf and rip currents" on the East Coast next week.',
#   'url': 'https://www.axios.com/2025/08/16/hurricane-erin-category-4-storm',
#   'urlToImage': 'https://images.axios.com/tdgfZRLIFUM7TbQbzeF1yLXSxWA=/0x0:2000x1125/1366x768/2025/08/16/1755361285060.jpeg',
#   'publishedAt': '2025-08-16T17:26:15Z',
#   'content': '<ul><li>Swells from Erin, which on Friday was at a Category 1, will impact the northern Leeward Islands, Virgin Islands, Puerto Rico, Hispaniola, and Turks and Caicos through the weekend.</li></ul>Th… [+2117 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': "Francesca Ebel, Robyn Dixon, Ellen Francis, Catherine Belton, Siobhán O'Grady",
#   'title': 'Russia sees victory in summit as Trump adopts Putin approach to ending war - The Washington Post',
#   'description': 'In President Donald Trump’s warm red-carpet greeting at the Alaska summit, Russians saw an opening to pull America away from its traditional allies in Europe.',
#   'url': 'https://www.washingtonpost.com/world/2025/08/16/putin-trump-russia-summit-ukraine-war/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/XHYZIRG4SBRDTOI7AJFFKALIXY.JPG&w=1440',
#   'publishedAt': '2025-08-16T16:39:16Z',
#   'content': 'MOSCOW For Russia, the results of the Alaska summit between President Donald Trump and President Vladimir Putin marked a turning point in U.S.-Russian relations underlined by the United States subseq… [+62 chars]'},
#  {'source': {'id': None,
#    'name': 'The Official Website of the Ultimate Fighting Championship'},
#   'author': None,
#   'title': 'Prelim Results | UFC 319: Du Plessis vs Chimaev - UFC.com',
#   'description': 'See The Fight Results, Watch Post-Fight Interviews With The Prelim Winners And More From UFC 319: Du Plessis vs Chimaev, Live From United Center In Chicago On August 16',
#   'url': 'https://www.ufc.com/news/chicago-prelim-results-du-plessis-chimaev-ufc-319',
#   'urlToImage': 'https://ufc.com/images/styles/card/s3/2025-08/030423-General-View-UFC-Octagon-GettyImages-1471305944.jpg?itok=B7T3XEJj',
#   'publishedAt': '2025-08-16T15:43:59Z',
#   'content': 'UFC 319: DU PLESSIS vs CHIMAEV\xa0takes place Saturday, August 16 at\xa0United Center with the main card at 10pm ET/7pm PT on ESPN+ PPV. The prelims will be available on ESPN (joined in progress at 7pm ET)… [+361 chars]'},
#  {'source': {'id': 'cbs-news', 'name': 'CBS News'},
#   'author': None,
#   'title': 'Man rescued by helicopter after 2 days trapped behind California waterfall - CBS News',
#   'description': 'Ryan Wardwell of California planned to rappel down waterfalls known as the Seven Teacups on Sunday, officials said.',
#   'url': 'https://www.cbsnews.com/news/man-rescued-after-2-days-trapped-behind-waterfall-california/',
#   'urlToImage': 'https://assets2.cbsnewsstatic.com/hub/i/r/2025/08/16/d491d293-6ae4-4150-b598-5319f0aea71f/thumbnail/1200x630/7a7f0d1d5257ea191fb30a61229bb223/screenshot-2025-08-16-at-10-57-34-am.png',
#   'publishedAt': '2025-08-16T15:04:44Z',
#   'content': 'California police used a helicopter to rescue a man who got trapped for two days behind a waterfall when the force of the water pushed him off his climbing lines, law enforcement officials said.\r\nRya… [+1070 chars]'},
#  {'source': {'id': None, 'name': 'Thetimes.com'},
#   'author': 'Lisa Verrico',
#   'title': 'Why two long-haired Swedes have Taylor Swift fans so excited - The Times',
#   'description': 'Max Martin has written more No 1s than anyone since the Beatles. Shellback is his screaming protégé. Now they’ve reunited with Swift for her new album',
#   'url': 'https://www.thetimes.com/culture/music/article/taylor-swift-max-martin-shellback-sgs52ffsm',
#   'urlToImage': 'https://www.thetimes.com/imageserver/image/%2Fff055e8b-4eae-46e7-9c0e-e14097905419.jpg?crop=1440%2C810%2C0%2C315&resize=1200',
#   'publishedAt': '2025-08-16T15:00:00Z',
#   'content': 'Taylor Swift set the clock ticking on her 12th album on Tuesday, fuelling rumours that the worlds most productive pop star had found a portal to more hours in the day than everyone else. The Life of … [+6345 chars]'},
#  {'source': {'id': 'politico', 'name': 'Politico'},
#   'author': 'Shia Kapos',
#   'title': 'Texas Democrats who left the state over redistricting will take part in national demonstration - Politico',
#   'description': 'Before returning to the Lone Star State, they’re set to take the stage in Chicago.',
#   'url': 'https://www.politico.com/news/2025/08/16/texas-democrats-house-redistricting-00512675',
#   'urlToImage': 'https://www.politico.com/dims4/default/resize/1200/quality/90/format/jpg?url=https%3A%2F%2Fstatic.politico.com%2F2d%2F49%2Fa30ff88e4acd9ccfa98c49fa78ff%2Fap25217017510695.jpg',
#   'publishedAt': '2025-08-16T14:42:25Z',
#   'content': 'Its been really hard for the members to stay away from Texas, from their jobs, from their kids and families, said state Rep. Vikki Goodwin, whos also running for the lieutenant governor seat in 2026.… [+2066 chars]'},
#  {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#   'author': None,
#   'title': 'Pakistan’s monsoon flooding death toll rises to 220 as forecasters warn of more rain to come - AP News',
#   'description': 'Pakistan officials said rain-related incidents have killed at least 220 people in a northwest district. Rescuers recovered 63 bodies overnight from homes in Buner devastated by flash floods and landslides, officials said Saturday. Pakistan has experienced hig…',
#   'url': 'https://apnews.com/article/pakistan-floods-weather-d385bc06a9455218581eec84e492c65b',
#   'urlToImage': 'https://dims.apnews.com/dims4/default/44ff9ae/2147483647/strip/true/crop/3650x2053+0+190/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F18%2F07%2F722d36d561448cb03d501468e313%2Fbfd1b3d9eb78400189b6266ccd2e05d8',
#   'publishedAt': '2025-08-16T14:41:00Z',
#   'content': 'BUNER, Pakistan (AP) Flooding in a northwest Pakistani district has killed at least 220 people, officials said Saturday, as rescuers pulled 63 more bodies overnight from homes flattened by flash floo… [+4895 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Cameron Faulkner',
#   'title': 'The Pixel 9 Pro Fold is $600 off ahead of the new model’s debut - The Verge',
#   'description': 'Other deals include a $300 discount on Lenovo’s flawed yet capable Legion Go S, three for $30 4K Blu-rays, and more.',
#   'url': 'https://www.theverge.com/tech/760131/google-pixel-9-pro-fold-lenovo-legion-go-s-deal-sale',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/08/Google-Pixel-9-Pro-Fold-Deal.png?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2025-08-16T14:23:27Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nOther deals include a $300 discount on Lenovos flawed yet capable Legion Go S, three for $30 4K Blu-rays, and more.\r\nOther deals include a $300 discount on Lenov… [+5367 chars]'},
#  {'source': {'id': None, 'name': 'NPR'},
#   'author': '',
#   'title': 'Video shows prominent Palestinian prisoner for the first time in years - NPR',
#   'description': 'The world got a glimpse of Marwan Barghouti for the first time in years in a video of a far-right Israeli minister berating him.',
#   'url': 'https://www.npr.org/2025/08/16/g-s1-83121/marwan-barghouti-video-famous-palestinian-prisoner',
#   'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/5109x2874+0+107/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F4f%2Feb%2F43809ef14f93a4aa3d3feb541f40%2Fap25227501316327.jpg',
#   'publishedAt': '2025-08-16T13:18:56Z',
#   'content': "TEL AVIV, Israel The world got a glimpse of one of the most famous Palestinian prisoners in Israel on Friday, Marwan Barghouti, for the first time in years.\r\nA video posted by Israel's far-right nati… [+4094 chars]"},
#  {'source': {'id': 'cbs-news', 'name': 'CBS News'},
#   'author': None,
#   'title': 'Hundreds may have been exposed to rabies at bat-infested cabins in Grand Teton National Park - CBS News',
#   'description': 'Up to 500 people stayed at the eight Grand Teton National Park cabins that were affected, officials said.',
#   'url': 'https://www.cbsnews.com/news/grand-teton-national-park-rabies-exposure-cabins-guests-wyoming/',
#   'urlToImage': 'https://assets1.cbsnewsstatic.com/hub/i/r/2025/08/16/ac2dcedb-5b71-43cd-b13a-5b72ea62bbe7/thumbnail/1200x630/526bff4c487223406a424700b3a31e20/ap25227779670536.jpg',
#   'publishedAt': '2025-08-16T12:20:47Z',
#   'content': "Health officials are working to alert hundreds of people in dozens of states and several countries who may have been exposed to rabies in bat-infested cabins in Wyoming's Grand Teton National Park ov… [+3662 chars]"},
#  {'source': {'id': None, 'name': 'mlive.com'},
#   'author': 'Aaron McMann | amcmann@mlive.com',
#   'title': 'NCAA report: Harbaugh viewed Michigan compliance staff as ‘thorn in his side’ - MLive.com',
#   'description': "The 74-page NCAA report detailed the rift between Jim Harbaugh's football program and the Michigan compliance department.",
#   'url': 'https://www.mlive.com/wolverines/2025/08/ncaa-report-harbaugh-viewed-michigan-compliance-staff-as-thorn-in-his-side.html',
#   'urlToImage': 'https://www.mlive.com/resizer/v2/YX5AJRZOLFCNLKG2CX5JIXINZ4.JPG?auth=cc2e7cb71f2e142680d1330f5e5c419c7bd90c76ab6e3804b1096598d0d8a76a&width=1280&quality=90',
#   'publishedAt': '2025-08-16T12:06:00Z',
#   'content': 'While Connor Stalions and his sign-stealing operation at Michigan took center stage Friday, there was a behind-the-scenes feud bubbling over between Jim Harbaugh and the schools compliance department… [+4874 chars]'},
#  {'source': {'id': None, 'name': 'BBC News'},
#   'author': None,
#   'title': 'William and Kate set to move to new Berkshire home - BBC',
#   'description': 'Kensington Palace says the Prince and Princess of Wales will move to Forest Lodge later in the year.',
#   'url': 'https://www.bbc.com/news/articles/cpwyk1v0p8yo',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/f1c3/live/fc515f80-7aa1-11f0-a69a-95efe7e2a480.jpg',
#   'publishedAt': '2025-08-16T11:23:31Z',
#   'content': 'William and Kate are moving into Forest Lodge in Windsor\r\nThe Prince and Princess of Wales are set to move into a new home in Berkshire.\r\nWilliam and Catherine will move to the eight-bedroom Forest L… [+2136 chars]'},
#  {'source': {'id': None, 'name': 'Android Central'},
#   'author': 'Nickolas Diaz',
#   'title': "Google's Gemini gets teased in latest Pixel 10 photography clip - Android Central",
#   'description': "The company's AI is all over its devices, and it's on the way to make capturing memories even easier.",
#   'url': 'https://www.androidcentral.com/phones/google-pixel/google-pixel-10-series-teaser-gemini-photography-features',
#   'urlToImage': 'https://cdn.mos.cms.futurecdn.net/rj2RiPCrqxpXpK6XxBUkcF.jpg',
#   'publishedAt': '2025-08-16T11:22:00Z',
#   'content': "What you need to know\r\n<ul><li>Google officially teased a few AI-powered features for the Pixel 10 on X via a short teaser clip.</li><li>The video seemingly teased the series' strong telephoto capabi… [+3582 chars]"},
#  {'source': {'id': None, 'name': 'MarketWatch'},
#   'author': 'Tomi Kilgore',
#   'title': 'Why UnitedHealth? Buying the stock was actually a ‘classic Buffett move.’ - MarketWatch',
#   'description': 'Shares of some UnitedHealth peers got a bump, and they all look cheaper based on price relative to expected earnings',
#   'url': 'https://www.marketwatch.com/story/why-unitedhealth-buying-the-stock-was-actually-a-classic-buffett-move-df763d81',
#   'urlToImage': 'https://images.mktw.net/im-26310569/social',
#   'publishedAt': '2025-08-16T11:00:00Z',
#   'content': 'UnitedHealth Group Inc. had been pretty much abandoned by Wall Street, but it was the stock of the day on Friday after Warren Buffett said it was time to start buying into the health insurer.\r\nBuffet… [+169 chars]'},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'See full bio',
#   'title': 'iPhone 17 vs. 17 Air, 17 Pro, 17 Pro Max: All the Rumored Specs Compared - CNET',
#   'description': "Here's how Apple's iPhone 17 lineup will differ -- at least according to rumors we've heard.",
#   'url': 'https://www.cnet.com/tech/mobile/iphone-17-vs-17-air-17-pro-17-pro-max-all-the-rumored-specs-compared/',
#   'urlToImage': 'https://www.cnet.com/a/img/resize/552e099164dae5b22840cf845e9bd3a2f4874ba0/hub/2024/09/18/f4dfbd54-08f9-42cc-9309-1c3923a06558/iphone-16-plus-pro-pro-max-family-4559.jpg?auto=webp&fit=crop&height=675&width=1200',
#   'publishedAt': '2025-08-16T11:00:00Z',
#   'content': "Normally, we wait until phones are released to compare them, but Apple's next iPhone models are so eagerly awaited that we'll make an exception. We're basing our comparisons on the most credible rumo… [+7029 chars]"},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Sabrina Malhi',
#   'title': 'Another covid summer wave is here, but the future of vaccines is unclear - The Washington Post',
#   'description': 'Updated coronavirus vaccines may not be available until mid-September, and people who are not considered high risk may not be able to access them.',
#   'url': 'https://www.washingtonpost.com/health/2025/08/16/covid-wave-vaccines-xfg/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/GMB3PXLMDEC7N6ZEEHTITSC4IQ.jpg&w=1440',
#   'publishedAt': '2025-08-16T10:32:12Z',
#   'content': 'Coronavirus infections are climbing again, marking another summer wave as children go back to school.\r\nBut this uptick arrives with an added layer of uncertainty because its unclear when and which Am… [+46 chars]'},
#  {'source': {'id': 'fortune', 'name': 'Fortune'},
#   'author': 'Dave Smith',
#   'title': 'Meta spends more guarding Mark Zuckerberg than Apple, Nvidia, Microsoft, Amazon, and Alphabet do for their own CEOs—combined - Fortune',
#   'description': 'Zuckerberg is not exactly the most popular guy.',
#   'url': 'https://fortune.com/2025/08/16/mark-zuckerberg-meta-security-detail-costs-apple-nvidia-microsoft-amazon-alphabet-ceos/',
#   'urlToImage': 'https://fortune.com/img-assets/wp-content/uploads/2025/08/GettyImages-2173579376-e1755280938620.jpg?resize=1200,600',
#   'publishedAt': '2025-08-16T10:03:00Z',
#   'content': 'Mark Zuckerberg goes to great lengths to protect himself. It makes sense: Critics say his social networks are bad for your mental health, hes aggressively hiring people across Silicon Valley to staff… [+4098 chars]'},
#  {'source': {'id': None, 'name': 'BBC News'},
#   'author': 'Isabelle Gerretsen',
#   'title': 'An interstellar visitor and hairy caterpillars: The best science pictures of the week - BBC',
#   'description': 'The most striking science photos of the week: including the Perseid meteor shower and glowing underwater wonders.',
#   'url': 'https://www.bbc.com/future/article/20250815-the-best-science-pictures-of-the-week',
#   'urlToImage': 'https://ychef.files.bbci.co.uk/624x351/p0lx4spf.jpg',
#   'publishedAt': '2025-08-16T09:00:56Z',
#   'content': 'The most striking science photos of the week: including the Perseid meteor shower and glowing underwater wonders.\r\nRecord warm seas have brought an extraordinary range of new species to UK waters. Br… [+1318 chars]'},
#  {'source': {'id': None, 'name': 'NPR'},
#   'author': '',
#   'title': 'Electricity prices are climbing more than twice as fast as inflation - NPR',
#   'description': "Electricity prices are rising more than twice as fast as overall inflation.  That's especially costly during the dog days of summer when air conditioners are working hardest.  In addition to hot weather, a variety of factors are causing power bills to climb, …",
#   'url': 'https://www.npr.org/2025/08/16/nx-s1-5502671/electricity-bill-high-inflation-ai',
#   'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/5184x2916+0+270/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F8f%2Fee%2F4603b8014644a3727bf4e39945b8%2Fken-thomas.jpeg',
#   'publishedAt': '2025-08-16T09:00:00Z',
#   'content': 'Ken Thomas woke up this past Wednesday to find the power had gone out at his house in Boca Raton. A text message from his utility said a piece of equipment had failed at 2 a.m. By the time a repair c… [+5199 chars]'},
#  {'source': {'id': None, 'name': 'Phys.Org'},
#   'author': 'Rice University',
#   'title': 'Scientists find new quantum behavior in unusual superconducting material - Phys.org',
#   'description': 'Researchers at Rice University and collaborating institutions have discovered direct evidence of active flat electronic bands in a kagome superconductor. This breakthrough could pave the way for new methods to design quantum materials—including superconductor…',
#   'url': 'https://phys.org/news/2025-08-scientists-quantum-behavior-unusual-superconducting.html',
#   'urlToImage': 'https://scx2.b-cdn.net/gfx/news/hires/2025/scientists-find-new-qu-1.jpg',
#   'publishedAt': '2025-08-16T07:16:23Z',
#   'content': 'Researchers at Rice University and collaborating institutions have discovered direct evidence of active flat electronic bands in a kagome superconductor. This breakthrough could pave the way for new … [+4198 chars]'},
#  {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#   'author': 'TOI+Lifestyle+Desk',
#   'title': 'New blood pressure guidelines by American Heart Association: Key takeaways - The Times of India',
#   'description': 'AHA/ACC release new blood pressure guideline',
#   'url': 'https://timesofindia.indiatimes.com/life-style/health-fitness/web-stories/new-blood-pressure-guidelines-by-american-heart-association-key-takeaways/photostory/123330234.cms',
#   'urlToImage': 'https://static.toiimg.com/thumb/msid-123330252,imgsize-332847,width-900,height-1200,resizemode-6/123330252.jpg',
#   'publishedAt': '2025-08-16T06:24:26Z',
#   'content': 'Adults should limit sodium to 2,300 mg daily, ideally 1,500 mg, following a heart-healthy plan like DASH with fruits, vegetables, whole grains, lean proteins, and healthy oils. Reduce alcoholless or … [+48 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Joe Rossignol',
#   'title': "Apple Watch Reportedly Set to Receive 'Significant Redesign' Next Year - MacRumors",
#   'description': 'At least one new Apple Watch model launching next year will feature a "significant redesign," according to Taiwanese supply chain publication...',
#   'url': 'https://www.macrumors.com/2025/08/15/apple-watch-significant-redesign-rumor/',
#   'urlToImage': 'https://images.macrumors.com/t/RdbYQo8geJeeGtMJCti_NSWhfcg=/1600x/article-new/2025/06/Apple-Watch-Ultra-2-Complications.jpg',
#   'publishedAt': '2025-08-15T20:31:42Z',
#   'content': 'At least one new Apple Watch model launching next year will feature a "significant redesign," according to Taiwanese supply chain publication DigiTimes.\r\nIn a paywalled report this week, citing suppl… [+2209 chars]'},
#  {'source': {'id': None, 'name': 'Nature.com'},
#   'author': None,
#   'title': 'Watch a human embryo implant itself — with brute force - Nature',
#   'description': 'Video provides an up-close look at a human embryo plunging into tissue that simulates the uterine lining.',
#   'url': 'https://www.nature.com/articles/d41586-025-02627-2',
#   'urlToImage': 'https://media.nature.com/lw1200/magazine-assets/d41586-025-02627-2/d41586-025-02627-2_51345240.jpg',
#   'publishedAt': '2025-08-15T18:14:50Z',
#   'content': None},
#  {'source': {'id': None, 'name': 'Umn.edu'},
#   'author': None,
#   'title': 'Quick takes: US COVID rise, at-home FluMist launch, polio in 4 countries - CIDRAP',
#   'description': 'The at-home FluMist option, the first of its kind, is available in 34 states for the upcoming flu season.',
#   'url': 'https://www.cidrap.umn.edu/covid-19/quick-takes-us-covid-rise-home-flumist-launch-polio-4-countries',
#   'urlToImage': 'https://www.cidrap.umn.edu/themes/custom/cidrap_theme/images/cidrap-og-image.jpg',
#   'publishedAt': '2025-08-15T17:20:00Z',
#   'content': None},
#  {'source': {'id': None, 'name': 'ScienceAlert'},
#   'author': 'Universe Today',
#   'title': 'JWST Delivers Bad News About Life on TRAPPIST-1 Planet - ScienceAlert',
#   'description': "When global events set our minds to wondering if humanity has what it takes to persist, it's natural to wonder about other worlds, other life, other intelligent species, and if those others might be better suited to survive whatever Great Filters they face.",
#   'url': 'https://www.sciencealert.com/jwst-delivers-bad-news-about-life-on-trappist-1-planet',
#   'urlToImage': 'https://www.sciencealert.com/images/2025/08/trappist.jpg',
#   'publishedAt': '2025-08-15T02:39:16Z',
#   'content': "When global events set our minds to wondering if humanity has what it takes to persist, it's natural to wonder about other worlds, other life, other intelligent species, and if those others might be … [+9477 chars]"}]

# %%
import chromadb
from chromadb.utils import embedding_functions

# %%
ef = embedding_functions.OpenAIEmbeddingFunction(
    api_key=os.getenv("OPENAI_API_KEY"),
    model_name="text-embedding-3-large"
)

# %%
chroma_client = chromadb.PersistentClient()

#collection = chroma_client.create_collection(name="headlines", embedding_function=ef)
collection = chroma_client.get_collection(name="headlines", embedding_function=ef)

# %%
articles = top_headlines["articles"]

for article in articles:
    collection.add(
        ids=[article["url"]],
        documents=[f"{article["title"]}\n\n{article["description"]}"]
    )

# %%
results = collection.query(
    query_texts=["Bob Odenkirk"],
    n_results=5
)

results
# Out:
# {'ids': [['http://www.hollywoodreporter.com/movies/movie-news/weapons-box-office-nobody-2-highest-to-lowest-1236346020/',
#    'https://www.npr.org/2025/08/16/g-s1-83121/marwan-barghouti-video-famous-palestinian-prisoner',
#    'https://www.axios.com/2025/08/12/trump-bls-ej-antoni-economists',
#    'https://www.ufc.com/news/chicago-prelim-results-du-plessis-chimaev-ufc-319',
#    'https://www.cbsnews.com/news/man-rescued-after-2-days-trapped-behind-waterfall-california/']],
#  'embeddings': None,
#  'documents': [["Box Office: ‘Nobody 2’ Can’t Stop ‘Weapons’ as Sydney Sweeney’s ‘Americana’ All-Out Bombs - The Hollywood Reporter\n\nSpike Lee's Denzel Washington-starrer 'Highest 2 Lowest' also may be struggling in its limited theatrical debut before landing relatively quickly on Apple TV+.",
#    'Video shows prominent Palestinian prisoner for the first time in years - NPR\n\nThe world got a glimpse of Marwan Barghouti for the first time in years in a video of a far-right Israeli minister berating him.',
#    '"Utterly unqualified": Trump BLS pick gets panned by conservative economists - Axios\n\nConservative economists cited examples of Trump\'s BLS pick appearing to misunderstand data he would be responsible for.',
#    'Prelim Results | UFC 319: Du Plessis vs Chimaev - UFC.com\n\nSee The Fight Results, Watch Post-Fight Interviews With The Prelim Winners And More From UFC 319: Du Plessis vs Chimaev, Live From United Center In Chicago On August 16',
#    'Man rescued by helicopter after 2 days trapped behind California waterfall - CBS News\n\nRyan Wardwell of California planned to rappel down waterfalls known as the Seven Teacups on Sunday, officials said.']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None, None, None, None]],
#  'distances': [[1.4614436626434326,
#    1.656195878982544,
#    1.7072486877441406,
#    1.7154252529144287,
#    1.7307366132736206]]}

# %%
filtered_results = []
for doc, dist in zip(results['documents'][0], results['distances'][0]):
    if dist <= 1.5:
        filtered_results.append(doc)

filtered_results
# Out:
# ["Box Office: ‘Nobody 2’ Can’t Stop ‘Weapons’ as Sydney Sweeney’s ‘Americana’ All-Out Bombs - The Hollywood Reporter\n\nSpike Lee's Denzel Washington-starrer 'Highest 2 Lowest' also may be struggling in its limited theatrical debut before landing relatively quickly on Apple TV+."]
